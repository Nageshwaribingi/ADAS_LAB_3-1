# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.metrics import accuracy_score,classification_report
import matplotlib.pyplot as plt
data=pd.read_csv("eye_closure.csv")
x=data[["closure_ratio","avg_closure_ms","blink_rate"]]
y=data["label"]
x_train,x_test,y_train,y_test=train_test_split(
x,y,test_size=0.25,random_state=42,stratify=y
)
model=DecisionTreeClassifier(
max_depth=4,
min_samples_leaf=3,
random_state=42
)
model.fit(x_train,y_train)
pred=model.predict(x_test)
print("Accuracy:",accuracy_score(y_test,pred))
print(classification_report(y_test,pred))
new_driver=[[0.48,850,4]]
print("Prediction:",model.predict(new_driver)[0])
plt.figure(figsize=(12,7))
plot_tree(model,feature_names=x.columns,
class_names=model.classes_,filled=True)
plt.show()
# Out:
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#        Alert       1.00      1.00      1.00         5
#       Drowsy       1.00      1.00      1.00         5
#
#     accuracy                           1.00        10
#    macro avg       1.00      1.00      1.00        10
# weighted avg       1.00      1.00      1.00        10
#
# Prediction: Drowsy
# /Users/nageshwaribingi/Desktop/3-1/ADAS/ADAS_3-1/.venv/lib/python3.14/site-packages/sklearn/utils/validation.py:2830: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
